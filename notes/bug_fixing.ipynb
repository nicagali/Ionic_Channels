# %%
# %load_ext autoreload
# %autoreload 2

import sys
import matplotlib.pyplot as plt
sys.path.append('../codes/')
import odeint_solver
import plotting_functions
from parameters import *
import tim
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ### Generate Triangular Potential

# %%
odeint_solver.triangular_potential(0, write=True)
fig, ax = plt.subplots()
plotting_functions.plot_voltage(ax, 'my_code')
# Out:
# 0

# %% [markdown]
# ### Compute $g_{\infty}$ fot this potential

# %%
odeint_solver.average_density_steady()
fig, ax = plt.subplots()
plotting_functions.plot_voltage(ax, which_code='my_code')
plotting_functions.plot_avdensity(ax, which_code='my_code')

# %%
fig, ax = plt.subplots()
plotting_functions.plot_avdensity(ax, which_code='my_code')
plotting_functions.plot_avdensity(ax, which_code='tim')

# %%
odeint_solver.euler_forward_solver('triangular')
fig, ax = plt.subplots(1,2, figsize=(10,5))
plotting_functions.plot_voltage(ax[0], 'my_code')
plotting_functions.plot_gsolution(ax[1], 'euler', 'my_code')
fig.tight_layout()

# %% [markdown]
# ## Tim

# %%
tim.tim_solver()

# %%
fig, ax = plt.subplots()
plotting_functions.plot_voltage(ax, 'tim')

# %%
fig, ax = plt.subplots()
plotting_functions.plot_voltage(ax, 'tim')
plotting_functions.plot_avdensity(ax, 'tim')

# %%
fig, ax = plt.subplots(1,2, figsize=(10,5))
plotting_functions.plot_voltage(ax[0], 'tim')
plotting_functions.plot_gsolution(ax[1], 'euler', 'tim')
fig.tight_layout()

# %%
fig, ax = plt.subplots()
plotting_functions.plot_conductance_voltage(ax, 'tim')
