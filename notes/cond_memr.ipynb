# %% [markdown]
# Here calculate the effective current through a memrisotrs when in series with a capacitor.

# %%
# %load_ext autoreload
# %autoreload 2

import sys
import matplotlib.pyplot as plt
sys.path.append('../codes/')
import odeint_solver
import capacitor_memristor_solver
import debugging_capacitor
import plotting_functions
from parameters_channels import *
import potential_shapes
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Only Memristor - Odeint
#
# Below external voltage, current and conductance of the channel when only memristor. The voltage throught the resistors coincides with the external voltage, only one differential equation is solved, for g, and the resulting current is found by multiplying g and V_g.

# %%
potential_shapes.potential(0, shape='sine' , write=True)
odeint_solver.odeint_solver_function(potential_shape='sine')
fig, ax = plt.subplots(1,3, figsize=(14,5))
plotting_functions.plot_voltage(ax[0])
plotting_functions.plot_current_voltage(ax[2], solution_type='odeint')
plotting_functions.plot_gsolution(ax[1], solver = 'odeint')
fig.tight_layout()
# Out:
# time at +  1.0 , time at - 9.0

# %%
potential_shapes.potential(0, shape='cosine' , write=True)
# capacitor_memristor_solver.odeint_solver_function()
debugging_capacitor.odeint_solver_function()
fig, ax = plt.subplots(1,3, figsize=(14,5))
plotting_functions.plot_current_voltage(ax[2], solution_type='odeint', capacitance=True)
plotting_functions.plot_voltage(ax[0])
plotting_functions.plot_gsolution(ax[1], solver = 'odeint', capacitance=True)
# plotting_functions.plot_gsolution(ax[1], solver = 'odeint', g0_ratio=False)
fig.tight_layout()

# fig, ax = plt.subplots(1,2, figsize=(10,5))
# plotting_functions.plot_voltage(ax[0])
# plotting_functions.plot_voltage(ax[1], capacitor=True, odeint=True)
# fig.tight_layout()
# Out:
# time at +  1.0 , time at - 9.0

# %%
potential_shapes.potential(0, shape='sine' , write=True)
# odeint_solver.odeint_solver_function(potential_shape='sine')
odeint_solver.euler_forward_solver(potential_shape='sine', conductance_numb=0)
fig, ax = plt.subplots(1,3, figsize=(14,5))
plotting_functions.plot_voltage(ax[0])
plotting_functions.plot_current_voltage(ax[1], solution_type='euler')
plotting_functions.plot_gsolution(ax[2], solver = 'euler', g0_ratio=False)
fig.tight_layout()
# Out:
# time at +  1.0 , time at - 9.0

# %%
potential_shapes.potential(0, shape='sine' , write=True)
capacitor_memristor_solver.euler_forward_solver()
fig, ax = plt.subplots(1,3, figsize=(14,5))
plotting_functions.plot_current_voltage(ax[0], solution_type='euler', capacitance=True)
plotting_functions.plot_gsolution(ax[1], solver = 'euler', g0_ratio=False, capacitance=True)
plotting_functions.plot_gsolution(ax[2], solver = 'euler', g0_ratio=False, capacitance=True)
plotting_functions.plot_gsolution(ax[2], solver = 'euler', g0_ratio=False)
fig.tight_layout()

fig, ax = plt.subplots(1,2, figsize=(10,5))
plotting_functions.plot_voltage(ax[0])
plotting_functions.plot_voltage(ax[0], capacitor=True, euler=True)
plotting_functions.plot_voltage(ax[1], capacitor=True, euler=True)
fig.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[87], line 4
#       2 capacitor_memristor_solver.euler_forward_solver()
#       3 fig, ax = plt.subplots(1,3, figsize=(14,5))
# ----> 4 plotting_functions.plot_current_voltage(ax[0], solution_type='euler', capacitance=True)
#       5 plotting_functions.plot_gsolution(ax[1], solver = 'euler', g0_ratio=False, capacitance=True)
#       6 plotting_functions.plot_gsolution(ax[2], solver = 'euler', g0_ratio=False, capacitance=True)
#
# File ~/nica/phd/Projects/Ionic_Channels/notes/../codes/plotting_functions.py:178, in plot_current_voltage(ax, solution_type, label, capacitance)
#     174     data = np.loadtxt(f"{DATA_PATH}solution_euler_g.txt", unpack=True)
#     176 conductance = np.array(data[1])
# --> 178 current = voltage*conductance*(g_0*10**(12))
#     180 ax.plot(voltage, current, **current_style)
#     182 ax.axhline(0, color='dimgray', lw=1)
#
# ValueError: operands could not be broadcast together with shapes (1000,) (1001,)
